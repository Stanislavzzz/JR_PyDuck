# %%
age = 25

# %%
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
year = 2026
print(type(year))
# Out:
# <class 'int'>

# %%
temp = -10
print(type(temp))
print(temp)
# Out:
# <class 'int'>
# -10

# %%
num_1 = 10
num_2 = 3

res_1 = num_1 + num_2
res_2 = num_1 - num_2
res_3 = num_1 / num_2
res_4 = num_1 * num_2
res_5 = num_1 // num_2
res_6 = num_1 % num_2

# %%
print(res_1)
print(res_2)
print(res_3)
print(type(res_3))
print(res_4)
print(res_5)
print(res_6)
# Out:
# 13
# 7
# 3.3333333333333335
# <class 'float'>
# 30
# 3
# 1

# %%
res = 2 + 2 * 2
print(res)
# Out:
# 6

# %%
res = (2 + 2) * 2
print(res)
# Out:
# 8

# %%
# print

print(2, 3, 4, 'qaz', '1qaz')
print(22, 33, 44, 'qaz', '1qaz', sep='-=!=-', end="=====")
print(222, 333, 444, 'qaz', '1qaz', sep='-')
print(5, 6, 7, 'qaz', '1qaz')
# Out:
# 2 3 4 qaz 1qaz
# 22-=!=-33-=!=-44-=!=-qaz-=!=-1qaz=====222-333-444-qaz-1qaz
# 5 6 7 qaz 1qaz

# %%
user_input = input()
print(user_input)
# Out:
# 123

# %%
user_input = input("Введи своё имя: ")
print(user_input)
# Out:
# Bob

# %%
user_age = input("Введи свой возраст: ")
print(type(user_age))
print(id(user_age))

user_age = int(user_age)
print(type(user_age))
print(id(user_age))
res = user_age + 1
print('Поздравляем! Тебе', res, 'лет')
# Out:
# <class 'str'>
# 139504536570544
# <class 'int'>
# 10447112
# Поздравляем! Тебе 24 лет

# %%
user_age = int(input("Введи свой возраст: "))

res = user_age + 1
print('Поздравляем! Тебе', res, 'лет')
# Out:
# Поздравляем! Тебе 24 лет

# %%
num = 10
num += 11
print(num)

num1 = 5
num1= num1 + 11
print(num1)
# Out:
# 21
# 16

# %%
num = 10
num //= 3
print(num)

num1 = 10
num1= num1 // 3
print(num1)
# Out:
# 3
# 3

# %%
num = 10
num *= 3
print(num)

num1 = 10
num1= num1 * 3
print(num1)
# Out:
# 30
# 30

# %%
num_1 = 10
num_2 = 7

res_1 = num_1 == num_2
res_2 = num_1 >= num_2
res_3 = num_1 < num_2
res_4 = num_1 != num_2
print(res_1)
print(type(res_1))
print(res_2)
print(type(res_2))
print(res_3)
print(type(res_3))
print(res_4)
print(type(res_4))
# Out:
# False
# <class 'bool'>
# True
# <class 'bool'>
# False
# <class 'bool'>
# True
# <class 'bool'>

# %%
# float

pi = 3.14
print(pi)
print(type(pi))

temp = -14.0
print(temp)
print(type(temp))

zero = 0.0
print(zero)
print(type(zero))
# Out:
# 3.14
# <class 'float'>
# -14.0
# <class 'float'>
# 0.0
# <class 'float'>

# %%
num = 1_000_000_1_2_3
print(num)
print(type(num))
# Out:
# 1000000123
# <class 'int'>

# %%
num = 1_000_000_1_2_3.345_567
print(num)
# Out:
# 1000000123.345567

# %%
num_1 = 10.1
num_2 = 3.1

res_1 = num_1 + num_2
res_2 = num_1 - num_2
res_3 = num_1 / num_2
res_4 = num_1 * num_2
res_5 = num_1 // num_2
res_6 = num_1 % num_2
res_7 = num_1 ** num_2

print(res_1)
print(res_2)
print(res_3)
print(res_4)
print(res_5)
print(res_6)
print(res_7)
# Out:
# 13.2
# 7.0
# 3.258064516129032
# 31.31
# 3.0
# 0.7999999999999994
# 1298.3633826837624

# %%
print(0.1 + 0.2)
# Out:
# 0.30000000000000004

# %%
res = 0.1 + 0.2
print(res)
new_res = round(res, 2)
print(new_res)
# Out:
# 0.30000000000000004
# 0.3

# %%
num = 12345.63519
print(round(num))
print(round(num, 1))
print(round(num, 2))
print(round(num, 3))
print(round(num, -1))
print(round(num, -2))
print(round(num, -3))
# Out:
# 12346
# 12345.6
# 12345.64
# 12345.635
# 12350.0
# 12300.0
# 12000.0

# %%
from decimal import Decimal
a = Decimal('0.1')
b = Decimal('0.2')
res = a + b
print(res)
print(type(res))
new = float(res)
print(new)
# Out:
# 0.3
# <class 'decimal.Decimal'>
# 0.3

# %%
# bool

# True
# False

is_sun = True
is_running = False

print(is_sun)
print(type(is_sun))

print(is_running)
print(type(is_running))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
num_1 = 10
num_2 = 7

res_1 = num_1 == num_2
res_2 = num_1 >= num_2
res_3 = num_1 < num_2
res_4 = num_1 != num_2
print(res_1)
print(type(res_1))
print(res_2)
print(type(res_2))
print(res_3)
print(type(res_3))
print(res_4)
print(type(res_4))

# %%
# and or not

res = True and True
print(res)

res = True and False
print(res)

res = True or False
print(res)

res = not True
print(res)
# Out:
# True
# False
# True
# False

# %%
# None

res = None
print(res)
print(type(res))
# Out:
# None
# <class 'NoneType'>
